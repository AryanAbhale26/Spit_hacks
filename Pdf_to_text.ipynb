# %%
import pdfplumber
from googletrans import Translator

# File path
file_path = r"C:\Users\Lenovo\Desktop\tsec\Hacks24-Sino_Mino_Chino\Data\157573123_mehqny2p4fxh4aszkkhudzdy.pdf"

# Initialize translator
translator = Translator()

# Open PDF file using pdfplumber
with pdfplumber.open(file_path) as pdf:
    # Iterate through each page of the PDF
    for page in pdf.pages:
        # Extract text from the current page
        text = page.extract_text()
        
        # Translate the extracted text to Hindi
        translated_text = translator.translate(text, dest='hi').text
        
        # Print the translated text
        print(translated_text)
        
        # Write the translated text to a file
        with open("translated_text_hindi.txt", mode='a', encoding='utf-8') as txt_file:
            txt_file.write(translated_text + '\n')
# Out:
# ।
# L38 - देहरादुन लैब 2 होम विजिट
# डॉ। लाल पाथलैब्स लिमिटेड दूसरी मंजिल, नंबर 65,
# बल्लुपुर- II रोड, क्यूबिक टॉवर, चक्राता
# नाम: श्री डेविंदर भसीन एकत्र: 20/12/2021 8:39:00 पूर्वाह्न
# प्राप्त: 20/12/2021 9:44:12 AM
# लैब नं।
# ए/सी स्थिति: पी रेफरी द्वारा: स्व रिपोर्ट स्थिति: अंतिम
# परीक्षण नाम परिणाम इकाइयों जैव।संदर्भ।मध्यान्तर
# SWASTHFIT टैक्स सेवर एडवांस पैकेज
# हेमोग्राम
# (विद्युत प्रतिबाधा और प्रवाह, केशिका फोटोमेट्री)
# हीमोग्लोबिन 15.40 ग्राम/डीएल 13.00 - 17.00
# पैक्ड सेल वॉल्यूम (PCV) 48.10 % 40.00 - 50.00
# आरबीसी काउंट 5.59 मिल/मिमी 3 4.50 - 5.50
# MCV 86.00 FL 83.00 - 101.00
# एमसीएच 27.50 पीजी 27.00 - 32.00
# MCHC 32.00 g/dl 31.50 - 34.50
# रेड सेल वितरण चौड़ाई (RDW) 12.90 % 11.60 - 14.00
# कुल ल्यूकोसाइट काउंट (टीएलसी) 7.71 तू/मिमी 3 4.00 - 10.00
# विभेदक ल्यूकोसाइट गिनती (डीएलसी)
# खंडित न्यूट्रोफिल 62.70 % 40.00 - 80.00
# लिम्फोसाइट्स 26.80 % 20.00 - 40.00
# मोनोसाइट्स 6.70 % 2.00 - 10.00
# Eosinophils 2.90 % 1.00 - 6.00
# बेसोफिल्स 0.90 % <2.00
# ...
